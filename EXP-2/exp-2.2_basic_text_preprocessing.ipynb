# %% [markdown]
# # 1. using NLTK

# %%
import pandas as pd
import nltk

# %%
from nltk import word_tokenize, sent_tokenize

# %%
with open("/Users/kartiken/Downloads/CLNLP-LAB/EXP-2/2.2_tokenization_data.txt", "r") as f:
    text = f.read()

# %%
text
# Out:
# 'Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence. It enables computers to understand human language. NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization.\n\nText tokenization is one of the first steps in NLP. Sentence tokenization divides a paragraph into individual sentences. Word tokenization divides each sentence into individual words and tokens.\n\nFor example, a chatbot receives thousands of messages every day. The system processes these messages and identifies useful information. This information can then be used to provide better responses to users.'

# %%
print(word_tokenize(text))
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'enables', 'computers', 'to', 'understand', 'human', 'language', '.', 'NLP', 'is', 'used', 'in', 'many', 'real-world', 'applications', ',', 'such', 'as', 'chatbots', ',', 'machine', 'translation', ',', 'sentiment', 'analysis', ',', 'and', 'text', 'summarization', '.', 'Text', 'tokenization', 'is', 'one', 'of', 'the', 'first', 'steps', 'in', 'NLP', '.', 'Sentence', 'tokenization', 'divides', 'a', 'paragraph', 'into', 'individual', 'sentences', '.', 'Word', 'tokenization', 'divides', 'each', 'sentence', 'into', 'individual', 'words', 'and', 'tokens', '.', 'For', 'example', ',', 'a', 'chatbot', 'receives', 'thousands', 'of', 'messages', 'every', 'day', '.', 'The', 'system', 'processes', 'these', 'messages', 'and', 'identifies', 'useful', 'information', '.', 'This', 'information', 'can', 'then', 'be', 'used', 'to', 'provide', 'better', 'responses', 'to'
# ...

# %%
print(sent_tokenize(text))
# Out:
# ['Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.', 'It enables computers to understand human language.', 'NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization.', 'Text tokenization is one of the first steps in NLP.', 'Sentence tokenization divides a paragraph into individual sentences.', 'Word tokenization divides each sentence into individual words and tokens.', 'For example, a chatbot receives thousands of messages every day.', 'The system processes these messages and identifies useful information.', 'This information can then be used to provide better responses to users.']

# %% [markdown]
# # 2. using spaCy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 765.6 kB/s  0:00:160:00:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
with open("/Users/kartiken/Downloads/CLNLP-LAB/EXP-2/2.2_tokenization_data.txt", "r") as f:
    text2 = f.read()

# %%
text2
# Out:
# 'Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence. It enables computers to understand human language. NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization.\n\nText tokenization is one of the first steps in NLP. Sentence tokenization divides a paragraph into individual sentences. Word tokenization divides each sentence into individual words and tokens.\n\nFor example, a chatbot receives thousands of messages every day. The system processes these messages and identifies useful information. This information can then be used to provide better responses to users.'

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "SpaCy is a powerful library for Natural Language Processing."
doc = nlp(text2)
print("Token\t\tPOS Tag")
print("-----------------------")
for token in doc:
    print(f"{token.text}\t\t{token.pos_}")
# Out:
# Token		POS Tag
# -----------------------
# Natural		PROPN
# Language		PROPN
# Processing		PROPN
# (		PUNCT
# NLP		PROPN
# )		PUNCT
# is		AUX
# a		DET
# fascinating		ADJ
# field		NOUN
# of		ADP
# Artificial		PROPN
# Intelligence		PROPN
# .		PUNCT
# It		PRON
# enables		VERB
# computers		NOUN
# to		PART
# understand		VERB
# human		ADJ
# language		NOUN
# .		PUNCT
# NLP		PROPN
# is		AUX
# used		VERB
# in		ADP
# many		ADJ
# real		ADJ
# -		PUNCT
# world		NOUN
# applications		NOUN
# ,		PUNCT
# such		ADJ
# as		ADP
# chatbots		NOUN
# ,		PUNCT
# machine		NOUN
# translation		NOUN
# ,		PUNCT
# sentiment		NOUN
# analysis		NOUN
# ,		PUNCT
# and		CCONJ
# text		NOUN
# summarization		NOUN
# .		PUNCT
#
#
# 		SPACE
# Text		NOUN
# tokenization		NOUN
# is		AUX
# one		NUM
# of		ADP
# the		DET
# first		ADJ
# steps		NOUN
# in		ADP
# NLP		PROPN
# .		PUNCT
# Sentence		NOUN
# tokenization		NOUN
# divides		VERB
# a		DET
# paragraph		NOUN
# into		ADP
# individual		ADJ
# sentences		NOUN
# .		PUNCT
# Word		NOUN
# ...

# %% [markdown]
# # 3 . without using NLTK/spacy

# %%
import re
with open("/Users/kartiken/Downloads/CLNLP-LAB/EXP-2/2.2_tokenization_data.txt", "r") as f:
    text3 = f.read()
def sentence_tokenize(text):
    sentences = re.split(r'(?<=[.!?])\s+', text3)
    return [s.strip() for s in sentences if s.strip()]
def word_tokenize(text):
    tokens = re.findall(r"\b\w+(?:[-']\w+)*\b|\S", text3)
    return tokens
sentences = sentence_tokenize(text3)
print("Sentence Tokenization:")
for i, sent in enumerate(sentences, 1):
    print(f"  {i}. {sent}")
print("\nWord Tokenization (all sentences):")
for sent in sentences:
    print(f"  {sent}")
    print(f"  Tokens: {word_tokenize(sent)}\n")
# Out:
# Sentence Tokenization:
#   1. Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.
#   2. It enables computers to understand human language.
#   3. NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization.
#   4. Text tokenization is one of the first steps in NLP.
#   5. Sentence tokenization divides a paragraph into individual sentences.
#   6. Word tokenization divides each sentence into individual words and tokens.
#   7. For example, a chatbot receives thousands of messages every day.
#   8. The system processes these messages and identifies useful information.
#   9. This information can then be used to provide better responses to users.
#
# Word Tokenization (all sentences):
#   Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.
# ...
